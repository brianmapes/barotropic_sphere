# %%
import xarray as xr

# %%
ds = xr.open_dataset('https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/M2I3NVAER')
# Out:
# /Users/brianmapes/opt/miniconda3/envs/barotropic/lib/python3.10/site-packages/xarray/coding/times.py:150: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 124672, lev: 72, lat: 361, lon: 576)
# Coordinates:
#   * time      (time) datetime64[ns] 1980-01-01 ... 2022-08-31T21:00:00
#   * lev       (lev) float64 992.5 977.5 962.5 947.5 ... 0.057 0.04 0.026 0.015
#   * lat       (lat) float64 -90.0 -89.5 -89.0 -88.5 ... 88.5 89.0 89.5 90.0
#   * lon       (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Data variables: (12/23)
#     airdens   (time, lev, lat, lon) float32 ...
#     bcphilic  (time, lev, lat, lon) float32 ...
#     bcphobic  (time, lev, lat, lon) float32 ...
#     delp      (time, lev, lat, lon) float32 ...
#     dms       (time, lev, lat, lon) float32 ...
#     du001     (time, lev, lat, lon) float32 ...
#     ...        ...
#     so4       (time, lev, lat, lon) float32 ...
#     ss001     (time, lev, lat, lon) float32 ...
#     ss002     (time, lev, lat, lon) float32 ...
#     ss003     (time, lev, lat, lon) float32 ...
# ...

# %%
ds.so4[0][5].plot()
